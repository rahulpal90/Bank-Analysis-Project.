# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulpal90/Bank-Analysis-Project./blob/main/Phone_Usage_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"/content/phone_usage_india.csv")
df
# Out:
#        Age  Gender   Location Phone Brand       OS  Screen Time (hrs/day)  \
# 0       53    Male     Mumbai        Vivo  Android                      4
# 1       60    Male      Delhi      Realme      iOS                      9
# 2       37  Female  Ahmedabad       Nokia  Android                      5
# 3       32    Male       Pune     Samsung  Android                     11
# 4       16    Male     Mumbai      Xiaomi      iOS                      2
# ...    ...     ...        ...         ...      ...                    ...
# 17681   27  Female     Mumbai       Apple      iOS                      7
# 17682   40  Female    Chennai        Oppo      iOS                     10
# 17683   34  Female  Ahmedabad      Realme  Android                      1
# 17684   22    Male  Hyderabad        Vivo  Android                      9
# 17685   43  Female    Kolkata        Oppo      iOS                      6
#
#        Data Usage (GB/month)  Calls Duration (mins/day)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17686 entries, 0 to 17685
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           17686 non-null  int64
#  1   Gender                        17686 non-null  object
#  2   Location                      17686 non-null  object
#  3   Phone Brand                   17686 non-null  object
#  4   OS                            17686 non-null  object
#  5   Screen Time (hrs/day)         17686 non-null  int64
#  6   Data Usage (GB/month)         17686 non-null  int64
#  7   Calls Duration (mins/day)     17686 non-null  int64
#  8   Number of Apps Installed      17686 non-null  int64
#  9   Social Media Time (hrs/day)   17686 non-null  float64
#  10  E-commerce Spend (INR/month)  17686 non-null  int64
#  11  Streaming Time (hrs/day)      17686 non-null  float64
# ...

# %%
df.shape
# Out:
# (17686, 15)

# %%
df.describe().T
# Out:
#                                 count         mean          std    min  \
# Age                           17686.0    37.584247    13.338252   15.0
# Screen Time (hrs/day)         17686.0     6.595160     3.195128    1.0
# Data Usage (GB/month)         17686.0    25.460025    14.124046    1.0
# Calls Duration (mins/day)     17686.0   151.452052    84.928146    5.0
# Number of Apps Installed      17686.0   104.584869    55.217097   10.0
# Social Media Time (hrs/day)   17686.0     3.252369     1.590223    0.5
# E-commerce Spend (INR/month)  17686.0  5075.707848  2871.604841  100.0
# Streaming Time (hrs/day)      17686.0     4.250616     2.155683    0.5
# Gaming Time (hrs/day)         17686.0     2.490874     1.446003    0.0
# Monthly Recharge Cost (INR)   17686.0  1042.785367   552.502067  100.0
#
#                                  25%     50%      75%      max
# Age                             26.0    38.0    49.00     60.0
# ...

# %%
df.isnull().sum()
# Out:
# Age                             0
# Gender                          0
# Location                        0
# Phone Brand                     0
# OS                              0
# Screen Time (hrs/day)           0
# Data Usage (GB/month)           0
# Calls Duration (mins/day)       0
# Number of Apps Installed        0
# Social Media Time (hrs/day)     0
# E-commerce Spend (INR/month)    0
# Streaming Time (hrs/day)        0
# Gaming Time (hrs/day)           0
# Monthly Recharge Cost (INR)     0
# Primary Use                     0
# dtype: int64

# %% [markdown]
# ## **Rows and column fetching**

# %%
# Column
df[["Age","Gender","OS"]]
# Out:
#        Age  Gender       OS
# 0       53    Male  Android
# 1       60    Male      iOS
# 2       37  Female  Android
# 3       32    Male  Android
# 4       16    Male      iOS
# ...    ...     ...      ...
# 17681   27  Female      iOS
# 17682   40  Female      iOS
# 17683   34  Female  Android
# 17684   22    Male  Android
# 17685   43  Female      iOS
#
# [17686 rows x 3 columns]

# %%
#Rows fetching using iloc
df.iloc[2:9:2]
# Out:
#    Age  Gender   Location Phone Brand       OS  Screen Time (hrs/day)  \
# 2   37  Female  Ahmedabad       Nokia  Android                      5
# 4   16    Male     Mumbai      Xiaomi      iOS                      2
# 6   57  Female    Lucknow       Apple      iOS                      6
# 8   46  Female    Kolkata        Oppo  Android                      5
#
#    Data Usage (GB/month)  Calls Duration (mins/day)  Number of Apps Installed  \
# 2                     12                         67                        96
# 4                      3                        236                        86
# 6                     35                        155                       123
# 8                     46                         21                       194
#
#    Social Media Time (hrs/day)  E-commerce Spend (INR/month)  \
# 2                          3.0                          2381
# 4                          5.5                           106
# ...

# %%
df.iloc[:15]
# Out:
#     Age  Gender   Location Phone Brand       OS  Screen Time (hrs/day)  \
# 0    53    Male     Mumbai        Vivo  Android                      4
# 1    60    Male      Delhi      Realme      iOS                      9
# 2    37  Female  Ahmedabad       Nokia  Android                      5
# 3    32    Male       Pune     Samsung  Android                     11
# 4    16    Male     Mumbai      Xiaomi      iOS                      2
# 5    21    Male     Jaipur        Oppo      iOS                      5
# 6    57  Female    Lucknow       Apple      iOS                      6
# 7    56    Male    Kolkata      Realme      iOS                      3
# 8    46  Female    Kolkata        Oppo  Android                      5
# 9    44    Male    Kolkata       Apple      iOS                     10
# 10   55    Male    Lucknow       Nokia  Android                      2
# 11   41  Female      Delhi        Oppo  Android                      8
# ...

# %% [markdown]
# **Both Rows and Columns Fetching**

# %%
df.iloc[1:10,[3,4,5]]
# Out:
#   Phone Brand       OS  Screen Time (hrs/day)
# 1      Realme      iOS                      9
# 2       Nokia  Android                      5
# 3     Samsung  Android                     11
# 4      Xiaomi      iOS                      2
# 5        Oppo      iOS                      5
# 6       Apple      iOS                      6
# 7      Realme      iOS                      3
# 8        Oppo  Android                      5
# 9       Apple      iOS                     10

# %%
df.iloc[0:20:2,[0,1,13,14]]
# Out:
#     Age  Gender  Monthly Recharge Cost (INR)    Primary Use
# 0    53    Male                          803      Education
# 2    37  Female                         1619  Entertainment
# 4    16    Male                          742   Social Media
# 6    57  Female                         1073   Social Media
# 8    46  Female                         1253  Entertainment
# 10   55    Male                         1098           Work
# 12   53    Male                          240      Education
# 14   33  Female                         1046  Entertainment
# 16   46    Male                         1679      Education
# 18   50  Female                         1639           Work

# %% [markdown]
# **Filtering Data**

# %%
df[df["Age"] > 30].head(3)
# Out:
#    Age  Gender   Location Phone Brand       OS  Screen Time (hrs/day)  \
# 0   53    Male     Mumbai        Vivo  Android                      4
# 1   60    Male      Delhi      Realme      iOS                      9
# 2   37  Female  Ahmedabad       Nokia  Android                      5
#
#    Data Usage (GB/month)  Calls Duration (mins/day)  Number of Apps Installed  \
# 0                     24                         38                       104
# 1                     28                         14                       169
# 2                     12                         67                        96
#
#    Social Media Time (hrs/day)  E-commerce Spend (INR/month)  \
# 0                          3.9                           469
# 1                          2.8                          4997
# 2                          3.0                          2381
#
#    Streaming Time (hrs/day)  Gaming Time (hrs/day)  \
# 0                       5.2                    4.1
# ...

# %%
#Filtering & Extracting Rows and Columns
df[df['Location']== 'Mumbai'].iloc[1:10,[1,2,3,13,14]]
# Out:
#     Gender Location   Phone Brand  Monthly Recharge Cost (INR)   Primary Use
# 4     Male   Mumbai        Xiaomi                          742  Social Media
# 16    Male   Mumbai         Apple                         1679     Education
# 44    Male   Mumbai  Google Pixel                          322     Education
# 46    Male   Mumbai       Samsung                         1319     Education
# 54    Male   Mumbai          Vivo                          122  Social Media
# 97    Male   Mumbai  Google Pixel                          443          Work
# 102   Male   Mumbai        Realme                          687          Work
# 119   Male   Mumbai        Realme                         1936          Work
# 122   Male   Mumbai       Samsung                         1562  Social Media

# %%
df[(df['Location']== 'Delhi') & (df['Age'] > 35)].iloc[1:10,[1,2,3,13,14]]
# Out:
#      Gender Location Phone Brand  Monthly Recharge Cost (INR)   Primary Use
# 11   Female    Delhi        Oppo                          151  Social Media
# 34     Male    Delhi        Vivo                         1935  Social Media
# 48     Male    Delhi      Xiaomi                          802  Social Media
# 64   Female    Delhi      Realme                         1699     Education
# 75   Female    Delhi        Oppo                          430        Gaming
# 92     Male    Delhi       Nokia                         1479        Gaming
# 128  Female    Delhi       Apple                         1574          Work
# 129  Female    Delhi    Motorola                          905  Social Media
# 151    Male    Delhi      Realme                         1318  Social Media
